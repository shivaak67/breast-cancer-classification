# %% [markdown]
# ## Preprocessing
#
# This notebook uses `src/preprocess.py` for loading, splitting, and scaling. The same functions are reused by `train.py` and `evaluate.py`.

# %%
import sys
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd().parent if (Path.cwd().parent / "src").exists() else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from preprocess import load_data, preprocess_data

# %%
df, target_names = load_data()
df.shape, target_names

# %%
data = preprocess_data()

X_train_scaled = data["X_train_scaled"]
X_test_scaled = data["X_test_scaled"]
y_train = data["y_train"]
y_test = data["y_test"]
scaler = data["scaler"]
feature_names = data["feature_names"]

# %%
X_train_scaled.shape, X_test_scaled.shape, y_train.shape, y_test.shape
# Out:
# ((455, 30), (114, 30), (455,), (114,))

# %%
# Scaling is handled inside preprocess_data(): fit on train, transform on test
scaler.mean_.shape, scaler.scale_.shape

# %%
pd.DataFrame(X_train_scaled, columns=feature_names).describe().loc[["mean", "std"]]
# Out:
#                 0             1             2             3             4   \
# mean -4.337434e-15  2.240942e-15 -7.437274e-16  1.503071e-16  5.223660e-15
# std   1.001101e+00  1.001101e+00  1.001101e+00  1.001101e+00  1.001101e+00
#
#                 5             6             7             8             9   \
# mean -2.775802e-15 -7.046866e-16  6.031805e-16 -3.263812e-15 -3.031519e-15
# std   1.001101e+00  1.001101e+00  1.001101e+00  1.001101e+00  1.001101e+00
#
#       ...            20            21            22            23  \
# mean  ...  4.060244e-16  5.676534e-15 -2.402962e-15 -1.022869e-15
# std   ...  1.001101e+00  1.001101e+00  1.001101e+00  1.001101e+00
#
#                 24            25            26            27            28  \
# mean  4.172487e-15 -5.465713e-16 -6.383172e-16 -4.489693e-16 -1.034581e-15
# std   1.001101e+00  1.001101e+00  1.001101e+00  1.001101e+00  1.001101e+00
#
#                 29
# mean -2.088683e-15
# std   1.001101e+00
#
# ...

# %%
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((455, 30), (114, 30))
